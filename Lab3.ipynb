# %% [markdown]
# **Goal of the Report**
#
# The Report consists of the Calfiorna Housing price Dataset with different dependent and independent variables using those data we can analyse and visualize the data

# %% [markdown]
# **Obtain Data**
# > https://www.kaggle.com/datasets/camnugent/california-housing-prices

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# **Exploratory Data Analysis (EDA)**

# %%
housing = pd.read_csv('data/housing.csv')
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms
# count  20640.000000  20640.000000        20640.000000  20640.000000  \
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income
# count    20433.000000  20640.000000  20640.000000   20640.000000  \
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %% [markdown]
# #### **Seaborn Scatter plot**
#
# Plot between Median House Value vs Median Income

# %%
sns.scatterplot(x='median_income', y='median_house_value', data=housing).set_title('Median House Value vs Median Income')
# Out:
# Text(0.5, 1.0, 'Median House Value vs Median Income')

# %% [markdown]
# Plot between Median House Value vs Population

# %%
sns.scatterplot(x='population', y='median_house_value', data=housing).set_title('Median House Value vs  population')
# Out:
# Text(0.5, 1.0, 'Median House Value vs  population')

# %% [markdown]
# Plot between Median House Value vs Households

# %%
sns.scatterplot(x='households', y='median_house_value', data=housing).set_title('Households vs Median Income')
# Out:
# Text(0.5, 1.0, 'Households vs Median Income')

# %% [markdown]
# #### **Model Linear Regression**

# %%
# median house value vs. median income

model1 = LinearRegression().fit(housing[['median_income']], housing['median_house_value'])

# median house value vs. population
model2 = LinearRegression().fit(housing[['population']], housing['median_house_value'])

# median house value vs. number of households
model3 = LinearRegression().fit(housing[['households']], housing['median_house_value'])

# %%
model = LinearRegression().fit(housing[['median_income']], housing['median_house_value'])
print(f"Intercept: {model.intercept_}")
print(f"Coefficients: {model.coef_}")
print(f"Mean squared error: {mean_squared_error(housing[['median_house_value']], model1.predict(housing[['median_income']]))}")
print(f"Mean absolute error: {mean_squared_error(housing[['median_house_value']], model1.predict(housing[['median_income']]))}")
# Out:
# Intercept: 45085.5767032679
# Coefficients: [41793.8492019]
# Mean squared error: 7011311502.929527
# Mean absolute error: 7011311502.929527

# %%
sns.scatterplot(x='median_income', y='median_house_value', data= housing)
sns.lineplot(x='median_income', y=model1.predict(housing[['median_income']]), color='red', data=housing)
plt.show()

# %%
model = LinearRegression().fit(housing[['population']], housing['median_house_value'])
print(f"Intercept: {model.intercept_}")
print(f"Coefficients: {model.coef_}")
print(f"Mean squared error: {mean_squared_error(housing[['median_house_value']], model2.predict(housing[['population']]))}")
print(f"Mean absolute error: {mean_squared_error(housing[['median_house_value']], model2.predict(housing[['population']]))}")
# Out:
# Intercept: 210436.26207627333
# Coefficients: [-2.51175277]
# Mean squared error: 13307412412.389355
# Mean absolute error: 13307412412.389355

# %%
sns.scatterplot(x='population', y='median_house_value', data= housing)
sns.lineplot(x='population', y=model2.predict(housing[['population']]), color='red', data=housing)
plt.show()

# %%
model = LinearRegression().fit(housing[['households']], housing['median_house_value'])
print(f"Intercept: {model.intercept_}")
print(f"Coefficients: {model.coef_}")
print(f"Mean squared error: {mean_squared_error(housing[['median_house_value']], model3.predict(housing[['households']]))}")
print(f"Mean absolute error: {mean_squared_error(housing[['median_house_value']], model3.predict(housing[['households']]))}")
# Out:
# Intercept: 196928.57716233088
# Coefficients: [19.87277516]
# Mean squared error: 13257776904.728533
# Mean absolute error: 13257776904.728533

# %%
sns.scatterplot(x='households', y='median_house_value', data= housing)
sns.lineplot(x='households', y=model3.predict(housing[['households']]), color='red', data=housing)
plt.show()

# %% [markdown]
# Conculsion

# %% [markdown]
# By the plot observation Model 1 is better than other two Models.
